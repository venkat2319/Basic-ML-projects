# %%
pip install pyfpgrowth
# Out:
# Collecting pyfpgrowth
#   Downloading pyfpgrowth-1.0.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 14.8 MB/s
# Building wheels for collected packages: pyfpgrowth
#   Building wheel for pyfpgrowth (setup.py) ... done
#   Created wheel for pyfpgrowth: filename=pyfpgrowth-1.0-py2.py3-none-any.whl size=5504 sha256=76f56dac4ff1088cffad0cbf37b7d0bfb9ae082cc03f8034ec86844f36713e88
#   Stored in directory: /root/.cache/pip/wheels/73/97/4b/f12ac994f6bbb99597396255435824c73ad3916be1e678be55
# Successfully built pyfpgrowth
# Installing collected packages: pyfpgrowth
# Successfully installed pyfpgrowth-1.0

# %%
import numpy as np
import pandas as pd
import pyfpgrowth

# %%
data=pd.read_csv('/content/sample_data/itemSet.csv',header = None)
transactions = []
for sublist in data.values.tolist():
  clean_sublist=[item for item in sublist if item is not np.nan]
  transactions.append(clean_sublist)
  patterns=pyfpgrowth.find_frequent_patterns(transactions,2)
  rules = pyfpgrowth.generate_association_rules(patterns,0.7)

# %%
data
# Out:
#                                  0
# 0               MILK,BREAD,BISCUIT
# 1    BREAD,MILK,BISCUIT,CORNFLAKES
# 2              BREAD,TEA,BOURNVITA
# 3             JAM,MAGGI,BREAD,MILK
# 4                MAGGI,TEA,BISCUIT
# 5              BREAD,TEA,BOURNVITA
# 6             MAGGI,TEA,CORNFLAKES
# 7          MAGGI,BREAD,TEA,BISCUIT
# 8              JAM,MAGGI,BREAD,TEA
# 9                       BREAD,MILK
# 10  COFFEE,COCK,BISCUIT,CORNFLAKES
# 11  COFFEE,COCK,BISCUIT,CORNFLAKES
# 12          COFFEE,SUGER,BOURNVITA
# 13               BREAD,COFFEE,COCK
# 14             BREAD,SUGER,BISCUIT
# 15         COFFEE,SUGER,CORNFLAKES
# 16           BREAD,SUGER,BOURNVITA
# 17              BREAD,COFFEE,SUGER
# 18              BREAD,COFFEE,SUGER
# 19      TEA,MILK,COFFEE,CORNFLAKES

# %%
print(patterns)
# Out:
# {('BREAD,TEA,BOURNVITA',): 2, ('COFFEE,COCK,BISCUIT,CORNFLAKES',): 2, ('BREAD,COFFEE,SUGER',): 2}

# %%
print(rules)
# Out:
# {}
